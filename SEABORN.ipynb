# %% [markdown]
# <a href="https://colab.research.google.com/github/ustab/NFL/blob/main/SEABORN.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
import seaborn as sns

# %%
df=sns.load_dataset('penguins')
df
# Out:
#     species     island  bill_length_mm  bill_depth_mm  flipper_length_mm  \
# 0    Adelie  Torgersen            39.1           18.7              181.0
# 1    Adelie  Torgersen            39.5           17.4              186.0
# 2    Adelie  Torgersen            40.3           18.0              195.0
# 3    Adelie  Torgersen             NaN            NaN                NaN
# 4    Adelie  Torgersen            36.7           19.3              193.0
# ..      ...        ...             ...            ...                ...
# 339  Gentoo     Biscoe             NaN            NaN                NaN
# 340  Gentoo     Biscoe            46.8           14.3              215.0
# 341  Gentoo     Biscoe            50.4           15.7              222.0
# 342  Gentoo     Biscoe            45.2           14.8              212.0
# 343  Gentoo     Biscoe            49.9           16.1              213.0
#
#      body_mass_g     sex
# 0         3750.0    Male
# 1         3800.0  Female
# ...

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 344 entries, 0 to 343
# Data columns (total 7 columns):
#  #   Column             Non-Null Count  Dtype
# ---  ------             --------------  -----
#  0   species            344 non-null    object
#  1   island             344 non-null    object
#  2   bill_length_mm     342 non-null    float64
#  3   bill_depth_mm      342 non-null    float64
#  4   flipper_length_mm  342 non-null    float64
#  5   body_mass_g        342 non-null    float64
#  6   sex                333 non-null    object
# dtypes: float64(4), object(3)
# memory usage: 18.9+ KB

# %%
df.describe().T
# Out:
#                    count         mean         std     min       25%      50%  \
# bill_length_mm     342.0    43.921930    5.459584    32.1    39.225    44.45
# bill_depth_mm      342.0    17.151170    1.974793    13.1    15.600    17.30
# flipper_length_mm  342.0   200.915205   14.061714   172.0   190.000   197.00
# body_mass_g        342.0  4201.754386  801.954536  2700.0  3550.000  4050.00
#
#                       75%     max
# bill_length_mm       48.5    59.6
# bill_depth_mm        18.7    21.5
# flipper_length_mm   213.0   231.0
# body_mass_g        4750.0  6300.0

# %%
#RELATIONAL PLOTS

# %%
#LINE PLOT
df.head()
# Out:
#   species     island  bill_length_mm  bill_depth_mm  flipper_length_mm  \
# 0  Adelie  Torgersen            39.1           18.7              181.0
# 1  Adelie  Torgersen            39.5           17.4              186.0
# 2  Adelie  Torgersen            40.3           18.0              195.0
# 3  Adelie  Torgersen             NaN            NaN                NaN
# 4  Adelie  Torgersen            36.7           19.3              193.0
#
#    body_mass_g     sex
# 0       3750.0    Male
# 1       3800.0  Female
# 2       3250.0  Female
# 3          NaN     NaN
# 4       3450.0  Female

# %%
sns.lineplot(data=df, x='flipper_length_mm',y='body_mass_g', hue='island');

# %%
sns.scatterplot(data=df, x='flipper_length_mm', y='body_mass_g');
sns.lineplot(data=df, x='flipper_length_mm', y='body_mass_g',hue='island');

# %%
sns.scatterplot(data=df, x='flipper_length_mm', y='body_mass_g',hue='sex');

# %%
plt.figure(figsize=(10, 8))
sns.scatterplot(data=df, x='flipper_length_mm', y='bill_depth_mm', hue='sex',size=350, style='sex', alpha=0.5, palette='viridis');

# %%
#seaborn plot types:
#distributions plots; kdeplot,rugplot,displot,histplot
#categorical plots;barplot, countplot, boxplot, swarmplot, violinplot
#comparison plots;jointplot, pairplot, catplot, matrix plot, grid plot

# %%
#rugplot her bir degere tick atiyor. degiskenin yogunlugunu gosterir yani
plt.figure(figsize=(15,8))
sns.rugplot(df.body_mass_g, height=0.50);

# %%
sns.kdeplot(df['body_mass_g'])
sns.rugplot(df['body_mass_g'],height=0.20);

# %%
sns.displot(data=df, x='body_mass_g')
sns.rugplot(df['body_mass_g'],height=0.20);

# %%
sns.histplot(data=df, x='body_mass_g')
sns.rugplot(data=df, x='body_mass_g', height=0.18);

# %%
#displot & histplot
#displot: represents the overall distribution of continuous data variables.
#hisplot:represents the distribution of one or more variables.

# %%
df=sns.load_dataset('penguins')
df
# Out:
#     species     island  bill_length_mm  bill_depth_mm  flipper_length_mm  \
# 0    Adelie  Torgersen            39.1           18.7              181.0
# 1    Adelie  Torgersen            39.5           17.4              186.0
# 2    Adelie  Torgersen            40.3           18.0              195.0
# 3    Adelie  Torgersen             NaN            NaN                NaN
# 4    Adelie  Torgersen            36.7           19.3              193.0
# ..      ...        ...             ...            ...                ...
# 339  Gentoo     Biscoe             NaN            NaN                NaN
# 340  Gentoo     Biscoe            46.8           14.3              215.0
# 341  Gentoo     Biscoe            50.4           15.7              222.0
# 342  Gentoo     Biscoe            45.2           14.8              212.0
# 343  Gentoo     Biscoe            49.9           16.1              213.0
#
#      body_mass_g     sex
# 0         3750.0    Male
# 1         3800.0  Female
# ...

# %%
sns.displot(data=df, x='body_mass_g', kde=True, hue='sex', bins=10);

# %%
plt.figure(figsize=(26,7))
sns.displot(data=df, x='body_mass_g', color='r', kde=True, hue='species', bins=10);

# %%
sns.histplot(df, x='body_mass_g', color='r', lw=4, ls='-.', bins=20);#histplot bir veya daha fazla variable in dagilimini gosterir. renklendirme olabilir

# %%
#kde:kernel density estimatee plot is a method for visualizing the distribution of observations in a dataset,
#represents data using a continues probability density curve

# %%
sns.set(style='whitegrid')
sns.kdeplot(df.body_mass_g, clip=[2500,6000]);#2500 gramdan itibaren kesme islemi yapiyoruz. buna gore 2500 den 6000 gr a  kadar olan kisim alinmis oldu.

# %%
sns.kdeplot(df.body_mass_g, clip=[2500,6000], bw_adjust=0.06, shade=True, color='y');#bw_adjust ck ayrintiya girmemizi sagladi ve cizginin sekli biraz bozuldu sanki mikroskopla bakmis gibi olduk.

# %%
sns.kdeplot(df.body_mass_g, bw_adjust=3, shade=True, color='b');#simdi uzaydan bakiyoruz ayrintilar kayboldu.

# %%
plt.figure(figsize=(10,6), dpi=500) #dpi kac tane nokta var demek
sns.kdeplot(df.body_mass_g, clip=[2000,6500], bw_adjust=2, shade=True, color='g');# uzaydan bakiyoruz ayrintilar kayip

# %%
  df.sex.value_counts()
# Out:
# Male      168
# Female    165
# Name: sex, dtype: int64

# %%
sns.countplot(df.sex);
# Out:
# /usr/local/lib/python3.7/dist-packages/seaborn/_decorators.py:43: FutureWarning: Pass the following variable as a keyword arg: x. From version 0.12, the only valid positional argument will be `data`, and passing other arguments without an explicit keyword will result in an error or misinterpretation.
#   FutureWarning

# %%
sns.countplot(df.species);
# Out:
# /usr/local/lib/python3.7/dist-packages/seaborn/_decorators.py:43: FutureWarning: Pass the following variable as a keyword arg: x. From version 0.12, the only valid positional argument will be `data`, and passing other arguments without an explicit keyword will result in an error or misinterpretation.
#   FutureWarning

# %%
plt.figure(figsize=(18,7));
fig,ax=plt.subplots();
ax=sns.countplot(df.species);
for p in ax.patches:
  ax.annotate((p.get_height()), (p.get_x()+0.3, p.get_height()+2));
# Out:
# /usr/local/lib/python3.7/dist-packages/seaborn/_decorators.py:43: FutureWarning: Pass the following variable as a keyword arg: x. From version 0.12, the only valid positional argument will be `data`, and passing other arguments without an explicit keyword will result in an error or misinterpretation.
#   FutureWarning

# %%
import numpy as np
#sns.barplot(data=df, x='sex', y='flipper_length_mm');#her iki secenek te calisiyor
sns.barplot(df.sex, df.flipper_length_mm);
# Out:
# /usr/local/lib/python3.7/dist-packages/seaborn/_decorators.py:43: FutureWarning: Pass the following variables as keyword args: x, y. From version 0.12, the only valid positional argument will be `data`, and passing other arguments without an explicit keyword will result in an error or misinterpretation.
#   FutureWarning

# %%
sns.barplot(df.sex, df.flipper_length_mm, estimator=np.std);
# Out:
# /usr/local/lib/python3.7/dist-packages/seaborn/_decorators.py:43: FutureWarning: Pass the following variables as keyword args: x, y. From version 0.12, the only valid positional argument will be `data`, and passing other arguments without an explicit keyword will result in an error or misinterpretation.
#   FutureWarning

# %%
sns.barplot(df.sex, df.flipper_length_mm, estimator=np.median);#estimator e dikkat, siyah cizgi ci i verir.
#
# Out:
# /usr/local/lib/python3.7/dist-packages/seaborn/_decorators.py:43: FutureWarning: Pass the following variables as keyword args: x, y. From version 0.12, the only valid positional argument will be `data`, and passing other arguments without an explicit keyword will result in an error or misinterpretation.
#   FutureWarning

# %%
plt.figure(figsize=(16,8),dpi=100)
sns.barplot(df.sex, df.flipper_length_mm, estimator=np.median, ci=95);#ci =95 dedim buna gore cizdirelim. cizdirmek icin iki degisken var.
# Out:
# /usr/local/lib/python3.7/dist-packages/seaborn/_decorators.py:43: FutureWarning: Pass the following variables as keyword args: x, y. From version 0.12, the only valid positional argument will be `data`, and passing other arguments without an explicit keyword will result in an error or misinterpretation.
#   FutureWarning

# %%
sns.boxplot(data=df, x='species', y='bill_depth_mm', hue='sex');
plt.legend(loc='best')

# %%
sns.boxenplot(data=df, x='species', y='bill_depth_mm', hue='sex');
plt.legend(loc='best');

# %%
plt.figure(figsize=(18,7), dpi=100)
sns.violinplot(data=df, x='species', y='bill_depth_mm', hue='sex',color='g', split=True);#split?
sns.boxplot(data=df,x='species', y='bill_depth_mm', hue='sex', color='r')
plt.legend(loc='best');

# %%
plt.figure(figsize=(18,7), dpi=100);
sns.swarmplot(data=df, x='sex', y='bill_depth_mm', hue='species', split=True);
# Out:
# /usr/local/lib/python3.7/dist-packages/seaborn/categorical.py:3002: UserWarning: The `split` parameter has been renamed to `dodge`.
#   warnings.warn(msg, UserWarning)

# %%
plt.figure(figsize=(12,7));
sns.swarmplot(data=df, x='body_mass_g',y='sex',hue='species', size=7, dodge=True);
plt.legend(loc='best');

# %%
plt.figure(figsize=(12,7));
sns.swarmplot(data=df, x='body_mass_g',y='sex',hue='species', size=7, dodge=False);# dodge =True denirse tur tur ayirir. yukaridaki grafige bak
plt.legend(loc='best');

# %%
plt.figure(figsize=(18,7), dpi=100)
sns.boxenplot(data=df, y='body_mass_g',x='sex', hue='species', dodge=True);# daha ayrintili quartile leri gosterir.
plt.legend(loc='best')
